# %% [markdown]
# <a href="https://colab.research.google.com/github/ViekyKayal/bulk_mail/blob/main/bulkgmail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
#upload your CV here
print(" Upload your sender csv file")
uploaded = files.upload()
sender_file = list(uploaded.keys())[0]
print(" upload your receiver csv file")
uploaded = files.upload()
receiver_file = list(uploaded.keys())[0]

print(" upload your email txt file")
uploaded = files.upload()
receiver_file = list(uploaded.keys())[0]

import smtplib, ssl, csv, random
from email.message import EmailMessage
from threading import Timer
"""
replyto = 'viekykayal19@gmail.com'
subject = 'Subject Of your Email'
name = 'Email Name'
"""
name = input("enter the sender name")
em =EmailMessage()
em['Reply-To'] = input("enter 'reply to' email id: ")
em['subject'] = input("enter subject of the email: ")
with open(random_file, 'r') as file:
    html_msg = file.read()
em.add_alternative(html_msg, subtype='html')
counter = {}
expired_data=[]

with open(sender_file) as f:
    data = [row for row in csv.reader(f)]
counter={row[0]:0 for row in data}

context = ssl.create_default_context()
server = smtplib.SMTP_SSL('smtp.gmail.com', 465, context=context)
sender=None
limit_mail= 450*len(data)
sent_mail=0
with open(receiver_file , 'r') as csvfile:
    datareader = csv.reader(csvfile)
    for row in datareader:
        if row==[]: continue
        if sender and counter[sender] >= 100:
            counter.pop(sender)
            data.remove(random_user)
            expired_data.append(random_user)
                   #Timer(delay(seconds), lambda: my_dict.update({key: new_value})).start()
            Timer(600, lambda: data.append(expired_data.pop(0))).start()
            sender=None
            server.close()
        if send_mail==limit_mail:
            break
        while sender is None:
            while data ==[]:
                pass
            random_user = random.choice(data)
            sender = random_user[0]
            password = random_user[1]
            del em['from']
            server.login(sender, password)
            print(row[0],em['To'])
            em['from'] = f'{name} <{sender}>'


        try:

            del em['To']
            em['To'] = row[0]
            server.send_message(em)
            counter[sender] += 1
            print(counter[sender], " emails sent", "From ", sender,  "To ", row[0] )
            sent_mail+=1
        except Exception as e:
            print(f"Error sending email From {sender} to {row[0]}:", e )
try:
    server.close()
except Exception as e:
    print("all servers are closed")
print("Emails Sent")
for sender, count in counter.items():
    print(f"{sender}: {count}")
# Out:
#      <input type="file" id="files-49900ea6-7ddd-4273-8b9c-00959c2510c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49900ea6-7ddd-4273-8b9c-00959c2510c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import smtplib, ssl, csv, random
from email.message import EmailMessage
from threading import Timer
"""
subject = 'Subject Of your Email'
name = 'Email Name'
"""
name = input("enter the sender name")
em =EmailMessage()
em['Reply-To'] = input("enter 'reply to' email id: ")
em['subject'] = input("enter subject of the email: ")
email_body=input("enter the mail body: ")
em.add_alternative(email_body, subtype='html')
counter = {}
expired_data=[]

with open(sender_file) as f:
    data = [row for row in csv.reader(f)]
counter={row[0]:0 for row in data}

context = ssl.create_default_context()
server = smtplib.SMTP_SSL('smtp.gmail.com', 465, context=context)
sender=None


with open(receiver_file , 'r') as csvfile:
    datareader = csv.reader(csvfile)
    for row in datareader:
        if row==[]: continue
        if sender and counter[sender] >= 100:
            counter.pop(sender)
            data.remove(random_user)
            expired_data.append(random_user)
                   #Timer(delay(seconds), lambda: my_dict.update({key: new_value})).start()
            Timer(600, lambda: data.append(expired_data.pop(0))).start()
            sender=None
            server.close()

        while sender is None:
            while data ==[]:
                pass
            random_user = random.choice(data)
            sender = random_user[0]
            password = random_user[1]
            del em['from']
            server.login(sender, password)
            print(row[0],em['To'])
            em['from'] = f'{name} <{sender}>'


        try:

            del em['To']
            em['To'] = row[0]
            server.send_message(em)
            counter[sender] += 1
            print(counter[sender], " emails sent", "From ", sender,  "To ", row[0] )

        except Exception as e:
            print(f"Error sending email From {sender} to {row[0]}:", e )
server.close()
print("Emails Sent")
for sender, count in counter.items():
    print(f"{sender}: {count}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-c95610f3cc89> in <cell line: 9>()
#       7 name = 'Email Name'
#       8 """
# ----> 9 name = input("enter the sender name")
#      10 em =EmailMessage()
#      11 em['Reply-To'] = input("enter 'reply to' email id: ")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
dir(EmailMessage)

# %%
counter = {}
expired_data=[]

with open(sender_file) as f:
    data = [row for row in csv.reader(f)]
counter={row[0]:0 for row in data}

context = ssl.create_default_context()
server = smtplib.SMTP_SSL('smtp.gmail.com', 465, context=context)
sender=None


with open(receiver_file , 'r') as csvfile:
    datareader = csv.reader(csvfile)
    for row in datareader:
        if row==[]: continue
        if sender and counter[sender] >= 100:
            counter.pop(sender)
            data.remove(random_user)
            expired_data.append(random_user)
                   #Timer(delay(seconds), lambda: my_dict.update({key: new_value})).start()
            Timer(600, lambda: data.append(expired_data.pop(0))).start()
            sender=None
            server.close()

        while sender is None:
            while data ==[]:
                pass
            random_user = random.choice(data)
            sender = random_user[0]
            password = random_user[1]
            del em['from']
            server.login(sender, password)
            print(row[0],em['To'])
            em['from'] = f'{name} <{sender}>'


        try:

            del em['To']
            em['To'] = row[0]
            server.send_message(em)
            counter[sender] += 1
            print(counter[sender], " emails sent", "From ", sender,  "To ", row[0] )

        except Exception as e:
            print(f"Error sending email From {sender} to {row[0]}:", e )
server.close()
print("Emails Sent")
for sender, count in counter.items():
    print(f"{sender}: {count}")
